# %% [markdown]
# Reading the CSV file

# %%
import pandas as pd
data = pd.read_csv('https://people.sc.fsu.edu/~jburkardt/data/csv/addresses.csv')
data.head()
# Out:
#                     John       Doe                 120 jefferson st.  \
# 0                   Jack  McGinnis                      220 hobo Av.
# 1          John "Da Man"    Repici                 120 Jefferson St.
# 2                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                    NaN  Blankman                               NaN
# 4  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#      Riverside   NJ   08075
# 0        Phila   PA    9119
# 1    Riverside   NJ    8075
# 2     SomeTown   SD   91234
# 3     SomeTown   SD     298
# 4  Desert City   CO     123

# %% [markdown]
# Subsetting with .loc[]

# %%
sample = pd.read_csv('sample.csv',index_col='avg_rating')
sample.head()
# Out:
#                                           title  voted_by  \
# avg_rating
# 4.500000                       Boudhanath Stupa      8897
# 4.500000                  Phewa Tal (Fewa Lake)      2988
# 4.500000                              Sarangkot      2199
# 4.500000                   Swayambhunath Temple      6203
# 4.500000                              Poon Hill      1477
# ...                                         ...       ...
# 4.771906    SITA (Travel Corporation India Ltd)         0
# 4.771906                         Himalayan Hike         0
# 4.771906                                 Harilo         0
# 4.771906                             Heli Sight         0
# 4.771906                              River Fun         0
#
#                                                         genre  history  \
# avg_rating
# 4.500000                                 Religious Sites          True
# 4.500000                                 Bodies of Water         False
# 4.500000                                       Mountains         False
# 4.500000                                 Religious Sites          True
# 4.500000                                       Mountains         False
# ...                                                       ...      ...
# 4.771906            Multi-day Tours   ,    Balloon Rides          True
# 4.771906               City Tours   ,    Multi-day Tours          True
# 4.771906                                 Farmers Markets         False
# 4.771906        Parasailing & Paragliding   ,    Multi-day...    False
# 4.771906        River Rafting & Tubing   ,    Taxis & Shut...    False
#
#             art_and_architecture  nature  adventure  entertainment  \
# avg_rating
# 4.500000                    True   False      False          False
# 4.500000                   False    True      False          False
# 4.500000                   False    True      False          False
# 4.500000                    True   False      False          False
# 4.500000                   False    True      False          False
# ...                          ...     ...        ...            ...
# 4.771906                   False   False      False          False
# 4.771906                    True   False      False           True
# 4.771906                   False   False      False           True
# 4.771906                   False   False       True          False
# 4.771906                   False   False       True          False
#
#             health_and_lifestyle   food  industries  religious
# avg_rating
# 4.500000                   False  False       False       True
# 4.500000                   False  False       False      False
# 4.500000                   False  False       False      False
# 4.500000                   False  False       False       True
# 4.500000                   False  False       False      False
# ...                          ...    ...         ...        ...
# 4.771906                   False  False       False      False
# 4.771906                   False  False       False      False
# 4.771906                   False   True       False      False
# 4.771906                   False  False       False      False
# 4.771906                   False  False       False      False
#
# [3313 rows x 12 columns]

# %%
here = sample.loc[4.5]
here
# Out:
#                                                      title  voted_by  \
# avg_rating
# 4.5                                       Boudhanath Stupa      8897
# 4.5                                  Phewa Tal (Fewa Lake)      2988
# 4.5                                              Sarangkot      2199
# 4.5                                   Swayambhunath Temple      6203
# 4.5                                              Poon Hill      1477
# ...                                                    ...       ...
# 4.5               Pathfinder Expeditions Private Day Tours         2
# 4.5         Everest Base Camp Heli Tour with Travel Beyond         2
# 4.5                        Nepal Travel Expedition (P) Ltd         2
# 4.5                                    Shree CC Handicraft         2
# 4.5                           Path of Dream Trek Adventure         8
#
#                                                         genre  history  \
# avg_rating
# 4.5                                      Religious Sites          True
# 4.5                                      Bodies of Water         False
# 4.5                                            Mountains         False
# 4.5                                      Religious Sites          True
# 4.5                                            Mountains         False
# ...                                                       ...      ...
# 4.5                                        Private Tours         False
# 4.5                                     Helicopter Tours         False
# 4.5             Multi-day Tours   ,    Canyoning & Rappell...     True
# 4.5                              Speciality & Gift Shops          True
# 4.5             Multi-day Tours   ,    River Rafting & Tub...     True
#
#             art_and_architecture  nature  adventure  entertainment  \
# avg_rating
# 4.5                         True   False      False          False
# 4.5                        False    True      False          False
# 4.5                        False    True      False          False
# 4.5                         True   False      False          False
# 4.5                        False    True      False          False
# ...                          ...     ...        ...            ...
# 4.5                        False    True      False          False
# 4.5                        False    True       True          False
# 4.5                        False   False      False          False
# 4.5                         True   False      False          False
# 4.5                        False   False      False          False
#
#             health_and_lifestyle   food  industries  religious
# avg_rating
# 4.5                        False  False       False       True
# 4.5                        False  False       False      False
# 4.5                        False  False       False      False
# 4.5                        False  False       False       True
# 4.5                        False  False       False      False
# ...                          ...    ...         ...        ...
# 4.5                        False  False       False      False
# 4.5                        False  False       False      False
# 4.5                        False  False       False      False
# 4.5                        False  False       False      False
# 4.5                        False  False       False      False
#
# [313 rows x 12 columns]

# %% [markdown]
# CrossTab

# %%
#importing packages
import pandas as pd
import numpy

# creating some arrays
a = numpy.array(["hello", "hello", "hello", "hello",
                 "hy", "hy", "hy", "hy",
                 "hello", "hello"],
                dtype=object)
  
b = numpy.array(["one", "one", "one", "two",
                 "one", "one", "one", "two",
                 "two", "two"],
                dtype=object)
  
c = numpy.array(["handsome","beautiful",
                 "hy", "hy", "beautiful",
                 "beautiful", "hy", "beautiful",
                 "beautiful", "beautiful"],
                dtype=object)
  
# form the cross tab
pd.crosstab(a, [b, c], rownames=['greetings'], colnames=['number', 'feature'])
# Out:
# number          one                   two
# feature   beautiful handsome hy beautiful hy
# greetings
# hello             1        1  1         2  1
# hy                2        0  1         1  0

# %% [markdown]
# CLEANING EMPTY CELL

# %%
data = pd.read_csv('data.csv')
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# 17        60  '2020/12/17'    100       120     300.0
# 18        45  '2020/12/18'     90       112       NaN
# 19        60  '2020/12/19'    103       123     323.0
# 20        45  '2020/12/20'     97       125     243.0
# 21        60  '2020/12/21'    108       131     364.2
# 22        45           NaN    100       119     282.0
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60      20201226    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
value = data["Calories"].median()

data["Calories"].fillna(value, inplace = True)
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# 17        60  '2020/12/17'    100       120     300.0
# 18        45  '2020/12/18'     90       112     291.2
# 19        60  '2020/12/19'    103       123     323.0
# 20        45  '2020/12/20'     97       125     243.0
# 21        60  '2020/12/21'    108       131     364.2
# 22        45           NaN    100       119     282.0
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60      20201226    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132     291.2
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %% [markdown]
# PLOTTING

# %%
import matplotlib.pyplot as plt

data.plot()

plt.show()

# %%
data.plot(kind='hist')
plt.show()
